# %% [markdown]
# # Analyze FiveThirtyEight Voter Power Index

# %%
import pandas as pd

# %% [markdown]
# ## Load "Voter Power Index" scores

# %%
voter_power_index = pd.read_csv("../data/fivethirtyeight/senate-voter-power-index.csv")

# %%
usps_state = {
    "AZ": "ARIZONA",
    "CA": "CALIFORNIA",
    "CT": "CONNECTICUT",
    "DE": "DELAWARE",
    "FL": "FLORIDA",
    "HI": "HAWAII",
    "IN": "INDIANA",
    "MA": "MASSACHUSETTS",
    "MD": "MARYLAND",
    "ME": "MAINE",
    "MI": "MICHIGAN",
    "MN": "MINNESOTA",
    "MO": "MISSOURI",
    "MS": "MISSISSIPPI",
    "MT": "MONTANA",
    "ND": "NORTH DAKOTA",
    "NE": "NEBRASKA",
    "NJ": "NEW JERSEY",
    "NM": "NEW MEXICO",
    "NV": "NEVADA",
    "NY": "NEW YORK",
    "OH": "OHIO",
    "PA": "PENNSYLVANIA",
    "RI": "RHODE ISLAND",
    "TN": "TENNESSEE",
    "TX": "TEXAS",
    "UT": "UTAH",
    "VA": "VIRGINIA",
    "VT": "VERMONT",
    "WA": "WASHINGTON",
    "WI": "WISCONSIN",
    "WV": "WEST VIRGINIA",
    "WY": "WYOMING"
}

# %%
voter_power_index["state_name"] = voter_power_index["state"].apply(usps_state.get)

# %%
voter_power_index.head()
# Out:
#   state       vpi   state_name
# 0    AZ  3.830486      ARIZONA
# 1    CA  0.000000   CALIFORNIA
# 2    CT  0.067179  CONNECTICUT
# 3    DE  0.078927     DELAWARE
# 4    FL  0.989972      FLORIDA

# %%
assert voter_power_index["state_name"].isnull().sum() == 0

# %% [markdown]
# ## Load state registered voter counts, by demographic
#
# Note: Population and registered-voter counts are *thousands*.

# %%
demo_by_state = pd.read_excel(
    "../data/census/table04b.xls",
    skiprows = 4,
    skipfooter = 5,
    na_values = [ "-" ]
)

demo_by_state.columns = [
   "state", "demographic", "total_pop", "total_citizen_pop", "total_registered", 
   "pct_registered", "moe_registered", "pct_registered_citizen", 
   "moe_registered_citizen", "total_voted", "pct_voted", "moe_voted", 
   "percent_voted_citizen", "moe_voted_citizen"
]

# %%
demo_by_state.head()
# Out:
#   state               demographic  total_pop  total_citizen_pop  \
# 0    US                     Total     245502             224059
# 1   NaN                      Male     118488             107554
# 2   NaN                    Female     127013             116505
# 3   NaN               White alone     192129             177865
# 4   NaN  White non-Hispanic alone     157395             154450
#
#    total_registered pct_registered moe_registered pct_registered_citizen  \
# 0          157596.0           64.2            0.3                   70.3
# 1           73761.0           62.3            0.4                   68.6
# 2           83835.0             66            0.4                     72
# 3          127463.0           66.3            0.3                   71.7
# 4          114151.0           72.5            0.3                   73.9
#
#   moe_registered_citizen  total_voted pct_voted moe_voted  \
# 0                    0.3     137537.0        56       0.3
# 1                    0.4      63801.0      53.8       0.4
# 2                    0.4      73735.0      58.1       0.4
# 3                    0.3     111891.0      58.2       0.3
# 4                    0.3     100849.0      64.1       0.4
#
#   percent_voted_citizen moe_voted_citizen
# 0                  61.4               0.3
# 1                  59.3               0.5
# 2                  63.3               0.4
# 3                  62.9               0.4
# 4                  65.3               0.4

# %%
demo_by_state["state"] = demo_by_state["state"].fillna(method="ffill")

# %%
demo_by_state.head()
# Out:
#   state               demographic  total_pop  total_citizen_pop  \
# 0    US                     Total     245502             224059
# 1    US                      Male     118488             107554
# 2    US                    Female     127013             116505
# 3    US               White alone     192129             177865
# 4    US  White non-Hispanic alone     157395             154450
#
#    total_registered pct_registered moe_registered pct_registered_citizen  \
# 0          157596.0           64.2            0.3                   70.3
# 1           73761.0           62.3            0.4                   68.6
# 2           83835.0             66            0.4                     72
# 3          127463.0           66.3            0.3                   71.7
# 4          114151.0           72.5            0.3                   73.9
#
#   moe_registered_citizen  total_voted pct_voted moe_voted  \
# 0                    0.3     137537.0        56       0.3
# 1                    0.4      63801.0      53.8       0.4
# 2                    0.4      73735.0      58.1       0.4
# 3                    0.3     111891.0      58.2       0.3
# 4                    0.3     100849.0      64.1       0.4
#
#   percent_voted_citizen moe_voted_citizen
# 0                  61.4               0.3
# 1                  59.3               0.5
# 2                  63.3               0.4
# 3                  62.9               0.4
# 4                  65.3               0.4

# %% [markdown]
# ## Join the two datasets

# %%
joined = pd.merge(
    demo_by_state,
    voter_power_index,
    left_on = "state",
    right_on = "state_name",
    how = "left",
    suffixes = ["", "_vpi"]
).dropna(subset = ["vpi"])

# %%
joined.head().T
# Out:
#                              33       34       35           36  \
# state                   ARIZONA  ARIZONA  ARIZONA      ARIZONA
# demographic               Total     Male   Female  White alone
# total_pop                  5196     2525     2671         4471
# total_citizen_pop          4585     2256     2329         3950
# total_registered           3145     1485     1660         2773
# pct_registered             60.5     58.8     62.2           62
# moe_registered              2.2      3.2      3.1          2.4
# pct_registered_citizen     68.6     65.8     71.3         70.2
# moe_registered_citizen      2.3      3.3      3.1          2.4
# total_voted                2769     1273     1496         2480
# pct_voted                  53.3     50.4       56         55.5
# moe_voted                   2.3      3.3      3.2          2.5
# percent_voted_citizen      60.4     56.5     64.2         62.8
# moe_voted_citizen           2.4      3.5      3.3          2.5
# state_vpi                    AZ       AZ       AZ           AZ
# vpi                     3.83049  3.83049  3.83049      3.83049
# state_name              ARIZONA  ARIZONA  ARIZONA      ARIZONA
#
#                                               37
# state                                    ARIZONA
# demographic             White non-Hispanic alone
# total_pop                                   2940
# total_citizen_pop                           2875
# total_registered                            2145
# pct_registered                                73
# moe_registered                               2.7
# pct_registered_citizen                      74.6
# moe_registered_citizen                       2.7
# total_voted                                 1963
# pct_voted                                   66.8
# moe_voted                                    2.9
# percent_voted_citizen                       68.3
# moe_voted_citizen                            2.9
# state_vpi                                     AZ
# vpi                                      3.83049
# state_name                               ARIZONA

# %%
joined["demo_power"] = joined["total_registered"] * joined["vpi"]

# %%
trimmed = (
    joined[
        ~joined["demographic"].isin(["Total", "Male", "Female", "White alone"]) &
        ~joined["demographic"].str.contains(r"combination")
    ]
    .sort_values("demo_power", ascending = False)
    .set_index([
        "state",
        "demographic"
    ])
    [[
        "total_registered",
        "vpi",
        "demo_power"
    ]]
)

trimmed.head(20)
# Out:
#                                         total_registered        vpi  \
# state         demographic
# TENNESSEE     White non-Hispanic alone            2601.0   4.709810
# NORTH DAKOTA  White non-Hispanic alone             399.0  29.625290
# MISSOURI      White non-Hispanic alone            2832.0   3.607548
# NEVADA        White non-Hispanic alone             879.0  10.799970
# TEXAS         White non-Hispanic alone            6822.0   1.309738
# ARIZONA       White non-Hispanic alone            2145.0   3.830486
# FLORIDA       White non-Hispanic alone            6432.0   0.989972
# MISSISSIPPI   White non-Hispanic alone            1056.0   5.337465
# INDIANA       White non-Hispanic alone            2832.0   1.238373
# TEXAS         Hispanic (of any race)              2654.0   1.309738
# MISSISSIPPI   Black alone                          632.0   5.337465
# MONTANA       White non-Hispanic alone             532.0   5.818740
# WEST VIRGINIA White non-Hispanic alone             860.0   3.154491
# NEVADA        Hispanic (of any race)               234.0  10.799970
# ARIZONA       Hispanic (of any race)               654.0   3.830486
# NEBRASKA      White non-Hispanic alone             882.0   2.829602
# TENNESSEE     Black alone                          519.0   4.709810
# TEXAS         Black alone                         1724.0   1.309738
# MINNESOTA     White non-Hispanic alone            2680.0   0.691564
# FLORIDA       Hispanic (of any race)              1779.0   0.989972
#
#                                           demo_power
# state         demographic
# TENNESSEE     White non-Hispanic alone  12250.215810
# NORTH DAKOTA  White non-Hispanic alone  11820.490710
# MISSOURI      White non-Hispanic alone  10216.575936
# NEVADA        White non-Hispanic alone   9493.173630
# TEXAS         White non-Hispanic alone   8935.032636
# ARIZONA       White non-Hispanic alone   8216.392470
# FLORIDA       White non-Hispanic alone   6367.501190
# MISSISSIPPI   White non-Hispanic alone   5636.363040
# INDIANA       White non-Hispanic alone   3507.072336
# TEXAS         Hispanic (of any race)     3476.044652
# MISSISSIPPI   Black alone                3373.277880
# MONTANA       White non-Hispanic alone   3095.569680
# WEST VIRGINIA White non-Hispanic alone   2712.862260
# NEVADA        Hispanic (of any race)     2527.192980
# ARIZONA       Hispanic (of any race)     2505.137844
# NEBRASKA      White non-Hispanic alone   2495.708964
# TENNESSEE     Black alone                2444.391390
# TEXAS         Black alone                2257.988312
# MINNESOTA     White non-Hispanic alone   1853.391520
# FLORIDA       Hispanic (of any race)     1761.160544

# %% [markdown]
# *Note: "White non-Hispanic alone" in North Dakota is index 389, while "Black alone or in combination" in Mississippi is index 284*

# %%
(
    trimmed.loc[("NORTH DAKOTA", "White non-Hispanic alone")]["demo_power"] 
    / trimmed.loc[("MISSISSIPPI", "Black alone")]["demo_power"]
)
# Out:
# 3.5041556404478604

# %% [markdown]
# ---
#
# ---
#
# ---
